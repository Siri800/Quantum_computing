# %% [markdown]
# <a href="https://colab.research.google.com/github/Siri800/Quantum_computing/blob/main/Quantum_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quantum Circuit Designer and Simulator
#
# ## Product 1 – Quantum Computing
#
# This project demonstrates the design, visualization, and simulation of fundamental quantum circuits using Qiskit.
#
# The project covers single-qubit gates, multi-qubit gates, quantum states, measurements, state visualizations, circuit simulation, transpilation, and theoretical-versus-simulated result comparison.

# %%
# %pip install qiskit==2.5.2 qiskit-aer matplotlib numpy streamlit pytest pylatexenc
# Out:
# Collecting qiskit==2.5.2
#   Downloading qiskit-2.5.2-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (14 kB)
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (2.1.3)
# Collecting streamlit
#   Downloading streamlit-1.62.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.13/dist-packages (8.4.2)
# Collecting pylatexenc
#   Downloading pylatexenc-2.11-py2.py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: scipy>=1.14 in /usr/local/lib/python3.13/dist-packages (from qiskit==2.5.2) (1.16.3)
# Collecting rustworkx>=0.15.0 (from qiskit==2.5.2)
#   Downloading rustworkx-0.18.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.13/dist-packages (from qiskit==2.5.2) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit==2.5.2)
#   Downloading stevedore-5.9.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.13/dist-packages (from qiskit==2.5.2) (4.16.0)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.13/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.13/dist-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=5.0.0 in /usr/local/lib/python3.13/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.13/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.13/dist-packages (from streamlit) (8.4.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from streamlit) (2.2.3)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.3-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: protobuf<8,>=5.26.1 in /usr/local/lib/python3.13/dist-packages (from streamlit) (5.29.6)
# Requirement already satisfied: pyarrow!=25.0.0,<26,>=7.0 in /usr/local/lib/python3.13/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.13/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.13/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: starlette<2,>=0.46.0 in /usr/local/lib/python3.13/dist-packages (from streamlit) (1.6.0)
# Requirement already satisfied: uvicorn<1,>=0.30.0 in /usr/local/lib/python3.13/dist-packages (from streamlit) (0.52.4)
# Requirement already satisfied: httptools<1,>=0.6.3 in /usr/local/lib/python3.13/dist-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio<5,>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from streamlit) (4.14.2)
# Requirement already satisfied: python-multipart<1,>=0.0.10 in /usr/local/lib/python3.13/dist-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets<17,>=12.0.0 in /usr/local/lib/python3.13/dist-packages (from streamlit) (15.0.1)
# Requirement already satisfied: itsdangerous<3,>=2.1.2 in /usr/local/lib/python3.13/dist-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.13/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.13/dist-packages (from pytest) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.13/dist-packages (from pytest) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.13/dist-packages (from pytest) (2.21.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.13/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.13/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2.25.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5,>=4.0.0->streamlit) (3.19)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas<4,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<4,>=1.4.0->streamlit) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.27->streamlit) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.27->streamlit) (2026.7.22)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.13/dist-packages (from uvicorn<1,>=0.30.0->streamlit) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2026.6.3)
# Downloading qiskit-2.5.2-cp310-abi3-manylinux_2_28_x86_64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 58.6 MB/s eta 0:00:00
# Downloading qiskit_aer-0.17.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 63.6 MB/s eta 0:00:00
# Downloading streamlit-1.62.0-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 50.4 MB/s eta 0:00:00
# Downloading pylatexenc-2.11-py2.py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 6.3 MB/s eta 0:00:00
# Downloading pydeck-0.9.3-py2.py3-none-any.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 58.5 MB/s eta 0:00:00
# Downloading rustworkx-0.18.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 57.8 MB/s eta 0:00:00
# Downloading stevedore-5.9.1-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: pylatexenc, stevedore, rustworkx, qiskit, pydeck, qiskit-aer, streamlit
# Successfully installed pydeck-0.9.3 pylatexenc-2.11 qiskit-2.5.2 qiskit-aer-0.17.2 rustworkx-0.18.1 stevedore-5.9.1 streamlit-1.62.0

# %% [markdown]
# # 1. Objectives
#
# The objectives of this project are:
#
# - To understand the fundamentals of qubits and quantum states.
# - To implement fundamental single-qubit quantum gates using Qiskit.
# - To implement multi-qubit quantum gates and circuits.
# - To design Bell and GHZ entangled states.
# - To simulate quantum circuits using Qiskit.
# - To visualize quantum states using Bloch spheres and Q-spheres.
# - To obtain measurement outcomes using repeated circuit execution.
# - To compare theoretical probabilities with simulated results.
# - To analyze quantum circuit transpilation.
# - To provide a functional quantum circuit designer and simulator.

# %% [markdown]
# # 2. Abstract
#
# This project presents a Quantum Circuit Designer and Simulator developed using Qiskit. The application demonstrates the design, visualization, and simulation of fundamental quantum circuits involving single-qubit and multi-qubit operations.
#
# The project implements Identity, Pauli-X, Pauli-Y, Pauli-Z, Hadamard, Phase-S, Phase-T, Rx, Ry, Rz, measurement, CNOT, CZ, SWAP, Toffoli, Bell-state, and GHZ-state circuits. Each circuit is simulated to obtain quantum statevectors, measurement outcomes, and probability distributions.
#
# State visualization techniques including Bloch spheres, Q-spheres, and measurement histograms are used to interpret the behavior of quantum states. The project also compares theoretical probabilities with simulated measurement results and analyzes circuit transpilation.
#
# A Streamlit-based circuit designer interface is included to allow users to select quantum circuits, adjust parameters, simulate circuits, and visualize their results.

# %% [markdown]
# # 3. Software and Hardware Requirements
#
# ## Software Requirements
#
# - Python 3.x
# - Jupyter Notebook
# - Qiskit
# - Qiskit Aer
# - NumPy
# - Matplotlib
# - Streamlit
# - Pytest
#
# ## Hardware Requirements
#
# The project can run on a standard computer with:
#
# - Minimum 4 GB RAM
# - Dual-core processor or better
# - Internet connection for installing Python packages
#
# No physical quantum computer is required because the circuits are simulated using Qiskit.

# %% [markdown]
# # 4. Introduction
#
# Quantum computing is a computing paradigm based on the principles of quantum mechanics. Classical computers process information using bits that can represent either 0 or 1. Quantum computers use quantum bits, called qubits, which can exist in a combination of computational basis states.
#
# A general single-qubit state is represented as:
#
# \[
# |\psi\rangle = \alpha|0\rangle + \beta|1\rangle
# \]
#
# where \(\alpha\) and \(\beta\) are complex probability amplitudes satisfying:
#
# \[
# |\alpha|^2 + |\beta|^2 = 1
# \]
#
# Quantum circuits use quantum gates to manipulate qubits. Gates such as Pauli-X, Pauli-Y, Pauli-Z and Hadamard operate on individual qubits, while gates such as CNOT, CZ, SWAP and Toffoli operate on multiple qubits.
#
# Quantum computing also supports important phenomena such as superposition and entanglement. Bell and GHZ states are examples of entangled quantum states.
#
# Measurements convert quantum information into classical outcomes. Because quantum measurement is probabilistic, repeated measurements are used to estimate the probability distribution of possible outcomes.
#
# In this project, Qiskit is used to create, visualize, and simulate fundamental quantum circuits.

# %% [markdown]
# # 5. Mathematical Background
#
# ## 5.1 Computational Basis States
#
# The two computational basis states of a qubit are:
#
# \[
# |0\rangle =
# \begin{bmatrix}
# 1\\
# 0
# \end{bmatrix}
# \]
#
# and
#
# \[
# |1\rangle =
# \begin{bmatrix}
# 0\\
# 1
# \end{bmatrix}
# \]
#
# ## 5.2 Superposition
#
# A qubit can exist in a superposition:
#
# \[
# |\psi\rangle = \alpha|0\rangle + \beta|1\rangle
# \]
#
# with:
#
# \[
# |\alpha|^2 + |\beta|^2 = 1
# \]
#
# ## 5.3 Pauli Gates
#
# The Pauli-X gate is:
#
# \[
# X =
# \begin{bmatrix}
# 0&1\\
# 1&0
# \end{bmatrix}
# \]
#
# The Pauli-Y gate is:
#
# \[
# Y =
# \begin{bmatrix}
# 0&-i\\
# i&0
# \end{bmatrix}
# \]
#
# The Pauli-Z gate is:
#
# \[
# Z =
# \begin{bmatrix}
# 1&0\\
# 0&-1
# \end{bmatrix}
# \]
#
# ## 5.4 Hadamard Gate
#
# The Hadamard gate is:
#
# \[
# H =
# \frac{1}{\sqrt{2}}
# \begin{bmatrix}
# 1&1\\
# 1&-1
# \end{bmatrix}
# \]
#
# It creates an equal superposition from a computational basis state.
#
# ## 5.5 Measurement Probability
#
# If:
#
# \[
# |\psi\rangle = \alpha|0\rangle + \beta|1\rangle
# \]
#
# then:
#
# \[
# P(0)=|\alpha|^2
# \]
#
# and
#
# \[
# P(1)=|\beta|^2
# \]
#
# ## 5.6 Entanglement
#
# For two qubits, the Bell state used in this project is:
#
# \[
# |\Phi^+\rangle =
# \frac{|00\rangle+|11\rangle}{\sqrt{2}}
# \]
#
# The GHZ state is:
#
# \[
# |GHZ\rangle =
# \frac{|000\rangle+|111\rangle}{\sqrt{2}}
# \]

# %% [markdown]
# # 6. Circuit Design Methodology
#
# The quantum circuits in this project are designed and simulated using the following procedure:
#
# 1. Initialize the required number of qubits.
# 2. Apply the required quantum gates.
# 3. Obtain the exact quantum state using a statevector simulation.
# 4. Calculate the theoretical probability distribution.
# 5. Add measurements to a copy of the circuit.
# 6. Execute repeated measurements using a specified number of shots.
# 7. Record the measurement counts.
# 8. Visualize the circuit and quantum state.
# 9. Compare theoretical probabilities with simulated results.
# 10. Analyze the circuit using Qiskit transpilation.
#
# The original circuit is kept without measurement so that the quantum state can be analyzed before measurement. A separate copy is used for measurement simulation.

# %% [markdown]
# # 7. Qiskit Implementation
#
# Qiskit is used as the primary quantum computing framework. The `QuantumCircuit` class is used to construct quantum circuits, while `Statevector` is used to obtain the exact quantum state before measurement.
#
# Qiskit's visualization tools are used for Bloch-sphere, Q-sphere, and histogram visualizations.
#
# The circuits are simulated using ideal statevector sampling with a configurable number of shots.

# %%
from math import pi
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.primitives import StatevectorSampler
from qiskit.visualization import (
    plot_bloch_multivector, plot_state_qsphere, plot_histogram
)

def simulate_ideal(circuit, shots=1024, seed=7):
    # Inspect the pure state before measurement.
    state = Statevector.from_instruction(circuit)

    # Sample a measured copy; keep the original unitary circuit intact.
    measured = circuit.copy()
    measured.measure_all()
    pub_result = (
        StatevectorSampler(seed=seed)
        .run([measured], shots=shots)
        .result()[0]
    )
    counts = pub_result.data.meas.get_counts()
    return state, counts

# %% [markdown]
# # 7.1 Single-Qubit Circuits
#
# This section implements the fundamental single-qubit circuits specified in Product 1.
#
# The circuits include Identity, Pauli-X, Pauli-Y, Pauli-Z, Hadamard, Phase-S, Phase-T, Rx, Ry, Rz, and Measurement.

# %%
qc = QuantumCircuit(1)
qc.id(0)
state, counts = simulate_ideal(qc)
print(state.data)
print(counts)
# Out:
# [1.+0.j 0.+0.j]
# {'0': 1024}

# %% [markdown]
# ## 7.1.1 Identity (I) Circuit
#
# The Identity gate leaves the quantum state unchanged.
#
# \[
# I|0\rangle = |0\rangle
# \]

# %% [markdown]
# ## 7.1.2 Pauli-X / Quantum NOT Circuit
#
# The Pauli-X gate acts as a quantum NOT operation.
#
# \[
# X|0\rangle = |1\rangle
# \]
#
# It changes the computational basis state from |0⟩ to |1⟩.

# %%
qc = QuantumCircuit(1)
qc.x(0)
state, counts = simulate_ideal(qc)
print(state.data)
print(counts)
# Out:
# [0.+0.j 1.+0.j]
# {'1': 1024}

# %% [markdown]
# ## 7.1.3 Pauli-Y Circuit
#
# The Pauli-Y gate changes the qubit state while introducing a complex phase.
#
# \[
# Y|0\rangle = i|1\rangle
# \]

# %%
qc = QuantumCircuit(1)
qc.y(0)
state, counts = simulate_ideal(qc)
print(state.data)
print(counts)
# Out:
# [0.+0.j 0.+1.j]
# {'1': 1024}

# %% [markdown]
# ## 7.1.4 Pauli-Z / Phase-Flip Circuit
#
# The Pauli-Z gate performs a phase flip.
#
# \[
# Z|0\rangle = |0\rangle
# \]
#
# \[
# Z|1\rangle = -|1\rangle
# \]
#
# The Hadamard gate is applied before Z in the implementation so that the phase effect becomes observable through subsequent analysis.

# %%
qc = QuantumCircuit(1)
qc.h(0)
qc.z(0)
state, counts = simulate_ideal(qc)
print(state.data)       # [1/sqrt(2), -1/sqrt(2)]
print(counts)           # roughly 50/50 in Z basis

# Add a final H to analyze the phase in the X basis.
analyzed = qc.copy()
analyzed.h(0)
_, analyzed_counts = simulate_ideal(analyzed)
print(analyzed_counts)  # {'1': 1024}
# Out:
# [ 0.70710678+0.j -0.70710678+0.j]
# {'1': 507, '0': 517}
# {'1': 1024}

# %% [markdown]
# ## 7.1.5 Hadamard / Superposition Circuit
#
# The Hadamard gate creates a superposition.
#
# \[
# H|0\rangle =
# \frac{|0\rangle+|1\rangle}{\sqrt{2}}
# \]
#
# Therefore, measuring the resulting state produces approximately 50% |0⟩ and 50% |1⟩.

# %%
qc = QuantumCircuit(1)
qc.h(0)
state, counts = simulate_ideal(qc, shots=1024)
print(state.data)
print(counts)
# Out:
# [0.70710678+0.j 0.70710678+0.j]
# {'1': 507, '0': 517}

# %% [markdown]
# ## 7.1.6 Phase-S Circuit
#
# The Phase-S gate introduces a phase shift of:
#
# \[
# \frac{\pi}{2}
# \]
#
# to the |1⟩ component of the quantum state.

# %%
qc = QuantumCircuit(1)
qc.h(0)
qc.s(0)
state, counts = simulate_ideal(qc)
print(state.data)
print(counts)
plot_bloch_multivector(state)
# Out:
# [0.70710678+0.j         0.        +0.70710678j]
# {'1': 507, '0': 517}

# %% [markdown]
# ## 7.1.7 Phase-T Circuit
#
# The Phase-T gate introduces a phase shift of:
#
# \[
# \frac{\pi}{4}
# \]
#
# to the |1⟩ component of the quantum state.

# %%
qc = QuantumCircuit(1)
qc.h(0)
qc.t(0)
state, counts = simulate_ideal(qc)
print(state.data)
print(counts)
plot_bloch_multivector(state)
# Out:
# [0.70710678+0.j  0.5       +0.5j]
# {'1': 507, '0': 517}

# %% [markdown]
# ## 7.1.8 Rotation-X (Rx) Circuit
#
# The Rx gate rotates a qubit around the X-axis of the Bloch sphere.
#
# The rotation angle used in this experiment is:
#
# \[
# \theta = \frac{\pi}{2}
# \]

# %%
theta = pi / 2
qc = QuantumCircuit(1)
qc.rx(theta, 0)
state, counts = simulate_ideal(qc)
print(state.data)
print(counts)
# Out:
# [0.70710678+0.j         0.        -0.70710678j]
# {'1': 507, '0': 517}

# %% [markdown]
# ## 7.1.9 Rotation-Y (Ry) Circuit
#
# The Ry gate rotates a qubit around the Y-axis of the Bloch sphere.
#
# The rotation angle used is:
#
# \[
# \theta = \frac{\pi}{2}
# \]

# %%
theta = pi / 2
qc = QuantumCircuit(1)
qc.ry(theta, 0)
state, counts = simulate_ideal(qc)
print(state.data)
print(counts)
# Out:
# [0.70710678+0.j 0.70710678+0.j]
# {'1': 507, '0': 517}

# %% [markdown]
# ## 7.1.10 Rotation-Z (Rz) Circuit
#
# The Rz gate rotates a qubit around the Z-axis of the Bloch sphere.
#
# The rotation angle used is:
#
# \[
# \theta = \frac{\pi}{2}
# \]

# %%
theta = pi / 2
qc = QuantumCircuit(1)
qc.h(0)
qc.rz(theta, 0)
state, counts = simulate_ideal(qc)
print(state.data)
print(counts)
# Out:
# [0.5-0.5j 0.5+0.5j]
# {'1': 507, '0': 517}

# %% [markdown]
# ## 7.1.11 Measurement Circuit
#
# Measurement converts a quantum state into classical information.
#
# For a Hadamard state:
#
# \[
# |\psi\rangle =
# \frac{|0\rangle+|1\rangle}{\sqrt{2}}
# \]
#
# the theoretical probabilities are:
#
# \[
# P(0)=0.5
# \]
#
# \[
# P(1)=0.5
# \]
#
# Repeated measurements are used to observe these probabilities experimentally through simulation.

# %%
qc = QuantumCircuit(1)
qc.h(0)

measured = qc.copy()
measured.measure_all()
result = (
    StatevectorSampler(seed=7)
    .run([measured], shots=1024)
    .result()[0]
)
counts = result.data.meas.get_counts()
print(counts)
# Out:
# {'1': 507, '0': 517}

# %% [markdown]
# # 7.2 Multi-Qubit Circuits
#
# This section implements multi-qubit quantum circuits including CNOT, CZ, SWAP, Toffoli, Bell-state, and GHZ-state circuits.

# %% [markdown]
# ## 7.2.1 Controlled-NOT (CNOT / CX)
#
# The CNOT gate uses one qubit as a control and another as a target.
#
# If the control qubit is |1⟩, the target qubit is flipped.

# %%
qc = QuantumCircuit(2)
qc.x(0)          # q0 becomes control value 1
qc.cx(0, 1)      # control q0, target q1
state, counts = simulate_ideal(qc)
print(state.probabilities_dict())
print(counts)
# Out:
# {np.str_('11'): np.float64(1.0)}
# {'11': 1024}

# %% [markdown]
# ## 7.2.2 Controlled-Z (CZ)
#
# The Controlled-Z gate applies a phase flip to the |11⟩ component of a two-qubit state.
#
# It is a two-qubit controlled phase operation.

# %%
qc = QuantumCircuit(2)
qc.h([0, 1])
qc.cz(0, 1)
state, counts = simulate_ideal(qc)
print(state.data)
print(counts)
# Out:
# [ 0.5+0.j  0.5+0.j  0.5+0.j -0.5+0.j]
# {'10': 250, '11': 257, '00': 265, '01': 252}

# %% [markdown]
# ## 7.2.3 SWAP Circuit
#
# The SWAP gate exchanges the quantum states of two qubits.
#
# In this experiment, the first qubit is initialized to |1⟩ and the SWAP operation transfers that state to the other qubit.

# %%
qc = QuantumCircuit(2)
qc.x(0)
qc.swap(0, 1)
state, counts = simulate_ideal(qc)
print(state.probabilities_dict())
print(counts)
# Out:
# {np.str_('10'): np.float64(1.0)}
# {'10': 1024}

# %% [markdown]
# ## 7.2.4 Toffoli / Controlled-Controlled-NOT Circuit
#
# The Toffoli gate contains two control qubits and one target qubit.
#
# The target qubit is flipped only when both control qubits are in the |1⟩ state.

# %%
qc = QuantumCircuit(3)
qc.x([0, 1])
qc.ccx(0, 1, 2)
state, counts = simulate_ideal(qc)
print(state.probabilities_dict())
print(counts)
# Out:
# {np.str_('111'): np.float64(1.0)}
# {'111': 1024}

# %% [markdown]
# ## 7.2.5 Bell-State / Entanglement Circuit
#
# The Bell state demonstrates quantum entanglement.
#
# The circuit applies a Hadamard gate to the first qubit followed by a CNOT gate.
#
# The resulting state is:
#
# \[
# |\Phi^+\rangle =
# \frac{|00\rangle+|11\rangle}{\sqrt{2}}
# \]
#
# Therefore:
#
# \[
# P(00)=0.5
# \]
#
# \[
# P(11)=0.5
# \]

# %%
bell = QuantumCircuit(2)
bell.h(0)
bell.cx(0, 1)
state, counts = simulate_ideal(bell, shots=1024)
print(state.data)
print(counts)
plot_state_qsphere(state)
plot_histogram(counts)
# Out:
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]
# {'11': 507, '00': 517}

# %% [markdown]
# ## 7.2.6 GHZ-State Circuit
#
# The Greenberger-Horne-Zeilinger state is a three-qubit entangled state.
#
# The circuit produces:
#
# \[
# |GHZ\rangle =
# \frac{|000\rangle+|111\rangle}{\sqrt{2}}
# \]
#
# The theoretical probabilities are:
#
# \[
# P(000)=0.5
# \]
#
# \[
# P(111)=0.5
# \]
#
# All other computational basis states have theoretical probability zero.

# %%
ghz = QuantumCircuit(3)
ghz.h(0)
ghz.cx(0, 1)
ghz.cx(0, 2)
state, counts = simulate_ideal(ghz, shots=1024)
print(state.data)
print(counts)
plot_state_qsphere(state)
plot_histogram(counts)
# Out:
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]
# {'111': 507, '000': 517}

# %% [markdown]
# # 8. Circuit Diagrams
#
# The following diagrams show the quantum gate arrangement for the implemented circuits. Qiskit's Matplotlib circuit drawer is used to generate the diagrams.

# %%
from qiskit import QuantumCircuit
from IPython.display import display

print("Identity:")
display(QuantumCircuit(1).draw("mpl"))
# Out:
# Identity:

# %% [markdown]
# # 9. Simulation Results
#
# The circuits are simulated using 1024 measurement shots. The statevector represents the exact ideal quantum state before measurement, while the measurement counts represent sampled outcomes.
#
# Because measurement is probabilistic, the simulated counts for superposition and entangled states may differ slightly from the exact theoretical probabilities.

# %% [markdown]
# # 10. Theoretical vs Simulated Results
#
# The theoretical probabilities are obtained from the exact statevector. The simulated probabilities are calculated from measurement counts.
#
# For each circuit:
#
# \[
# P_{\text{simulated}} =
# \frac{\text{measurement count}}{\text{total shots}}
# \]
#
# The difference between theoretical and simulated results is expected because measurements are sampled using a finite number of shots.

# %% [markdown]
# # 11. Transpilation Analysis
#
# Transpilation converts a quantum circuit into a form suitable for execution on a target quantum backend.
#
# The transpilation process can optimize the circuit and change its gate representation and circuit depth.
#
# In this project, the original circuit and transpiled circuit are compared using:
#
# - Circuit depth
# - Gate count
# - Gate types
# - Transpiled circuit diagram

# %% [markdown]
# # 12. Functional Circuit Designer Interface
#
# A Streamlit-based graphical interface is provided as part of the project. The interface allows users to select a circuit, specify rotation parameters and measurement shots, visualize the circuit, inspect the statevector, view probabilities, and analyze measurement results.

# %% [markdown]
# qiskit[all]~=2.5.1
# streamlit>=1.40
# matplotlib>=3.8
# numpy>=1.26

# %%
from math import pi
import streamlit as st
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.primitives import StatevectorSampler
from qiskit.visualization import (
    plot_bloch_multivector,
    plot_state_qsphere,
    plot_histogram,
)
CIRCUITS = [
    "Identity (I)", "Pauli-X", "Pauli-Y", "Pauli-Z",
    "Hadamard (H)", "Phase-S", "Phase-T",
    "Rx", "Ry", "Rz", "Measurement demo",
    "CNOT / CX", "Controlled-Z", "SWAP",
    "Toffoli / CCX", "Bell state", "GHZ state",
]

def build_circuit(name: str, theta: float) -> QuantumCircuit:
    if name in {
        "Identity (I)", "Pauli-X", "Pauli-Y", "Pauli-Z",
        "Hadamard (H)", "Phase-S", "Phase-T",
        "Rx", "Ry", "Rz", "Measurement demo",
    }:
        qc = QuantumCircuit(1, name=name)
    elif name in {"CNOT / CX", "Controlled-Z", "SWAP", "Bell state"}:
        qc = QuantumCircuit(2, name=name)
    else:
        qc = QuantumCircuit(3, name=name)

    if name == "Identity (I)":
        qc.id(0)
    elif name == "Pauli-X":
        qc.x(0)
    elif name == "Pauli-Y":
        qc.y(0)
    elif name == "Pauli-Z":
        qc.h(0); qc.z(0)       # exposes phase on |+>
    elif name == "Hadamard (H)":
        qc.h(0)
    elif name == "Phase-S":
        qc.h(0); qc.s(0)
    elif name == "Phase-T":
        qc.h(0); qc.t(0)
    elif name == "Rx":
        qc.rx(theta, 0)
    elif name == "Ry":
        qc.ry(theta, 0)
    elif name == "Rz":
        qc.h(0); qc.rz(theta, 0)
    elif name == "Measurement demo":
        qc.h(0)                # measurement is added later
    elif name == "CNOT / CX":
        qc.x(0); qc.cx(0, 1)
    elif name == "Controlled-Z":
        qc.h([0, 1]); qc.cz(0, 1)
    elif name == "SWAP":
        qc.x(0); qc.swap(0, 1)
    elif name == "Toffoli / CCX":
        qc.x([0, 1]); qc.ccx(0, 1, 2)
    elif name == "Bell state":
        qc.h(0); qc.cx(0, 1)
    elif name == "GHZ state":
        qc.h(0); qc.cx(0, 1); qc.cx(0, 2)
    return qc

# %%
def simulate(circuit: QuantumCircuit, shots: int, seed: int = 7):
    # Exact pre-measurement state.
    state = Statevector.from_instruction(circuit)

    # Add terminal measurements to a separate copy.
    measured = circuit.copy()
    measured.measure_all()

    # V2 sampler returns a PubResult with a BitArray named 'meas'.
    pub_result = (
        StatevectorSampler(seed=seed)
        .run([measured], shots=shots)
        .result()[0]
    )
    counts = pub_result.data.meas.get_counts()
    return state, measured, counts

# %%
st.set_page_config(
    page_title="Quantum Circuit Designer",
    page_icon="⚛",
    layout="wide",
)

st.title("Quantum Circuit Designer and Simulator")
st.caption("Build → inspect state → measure → interpret")

with st.sidebar:
    name = st.selectbox("Circuit", CIRCUITS)
    theta = st.slider(
        "Rotation angle θ (radians)",
        min_value=0.0, max_value=2*pi, value=pi/2, step=pi/16,
    )
    shots = st.select_slider(
        "Shots", options=[32, 128, 512, 1024, 4096, 8192], value=1024
    )

circuit = build_circuit(name, theta)
state, measured, counts = simulate(circuit, shots)

left, right = st.columns(2)
with left:
    st.subheader("Unitary circuit")
    st.pyplot(circuit.draw("mpl"))
    st.subheader("Measured circuit")
    st.pyplot(measured.draw("mpl"))

with right:
    st.subheader("State before measurement")
    st.code(str(state.data), language="text")
    st.write("Ideal probabilities:", state.probabilities_dict())
    st.subheader("Sampled counts")
    st.write(counts)
    st.pyplot(plot_histogram(counts))

st.subheader("State visualization")
if circuit.num_qubits == 1:
    st.pyplot(plot_bloch_multivector(state))
else:
    st.pyplot(plot_state_qsphere(state))

st.info(
    "Counts fluctuate because they are sampled. "
    "Statevector probabilities are the exact ideal prediction."
)
# Out:
# 2026-08-25 05:17:44.370 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.371 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.845
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.13/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-08-25 05:17:44.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.887 Session state does not function when running a script without `streamlit run`
# 2026-08-25 05:17:44.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:44.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:45.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:46.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:46.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:46.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:46.394 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:46.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:46.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:46.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:47.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:47.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:47.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:47.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:47.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-25 05:17:47.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# # 13. Challenges and Limitations
#
# The main challenges and limitations of the project include:
#
# - Quantum measurement is probabilistic, so finite-shot simulations may differ from theoretical probabilities.
# - Statevector simulation becomes computationally expensive as the number of qubits increases.
# - The current application focuses on ideal quantum simulation.
# - Real quantum hardware introduces noise, decoherence, gate errors, and measurement errors.
# - The circuit designer currently focuses on predefined fundamental circuits rather than arbitrary circuit construction.
# - Real quantum hardware access may be limited by queue time and backend availability.

# %%
from math import isclose

def probabilities(circuit):
    return Statevector.from_instruction(circuit).probabilities_dict()

# Deterministic X test
x = QuantumCircuit(1); x.x(0)
assert isclose(float(probabilities(x).get('1', 0)), 1.0)

# Bell support test
bell = QuantumCircuit(2); bell.h(0); bell.cx(0, 1)
p = probabilities(bell)
assert set(p) == {'00', '11'}
assert isclose(float(p['00']), 0.5, abs_tol=1e-12)
assert isclose(float(p['11']), 0.5, abs_tol=1e-12)

# GHZ support test
ghz = QuantumCircuit(3); ghz.h(0); ghz.cx(0,1); ghz.cx(0,2)
p = probabilities(ghz)
assert set(p) == {'000', '111'}

# %% [markdown]
# # 14. Conclusion
#
# The Quantum Circuit Designer and Simulator successfully demonstrates the implementation and simulation of fundamental quantum circuits using Qiskit.
#
# The project covers single-qubit gates, multi-qubit gates, quantum measurements, statevector analysis, Bloch-sphere visualization, Q-sphere visualization, and measurement histograms.
#
# Bell and GHZ circuits demonstrate quantum entanglement, while rotation and phase gates demonstrate transformations of quantum states.
#
# The project also provides a user-friendly Streamlit interface for selecting and simulating predefined quantum circuits. The theoretical and simulated results can be compared to understand the probabilistic nature of quantum measurement.

# %% [markdown]
# # 15. Future Enhancements
#
# Possible future improvements include:
#
# - Support for arbitrary user-defined quantum circuits.
# - Drag-and-drop circuit construction.
# - Noisy quantum simulation.
# - Error mitigation techniques.
# - Integration with IBM Quantum backends.
# - Real quantum hardware execution.
# - Additional quantum gates and algorithms.
# - Circuit optimization visualization.
# - Export of simulation results.
# - Interactive educational explanations for each quantum gate.

# %% [markdown]
# # 16. References
#
# 1. Qiskit Documentation – IBM Quantum.
# 2. IBM Quantum Learning Resources.
# 3. Nielsen, M. A. and Chuang, I. L., Quantum Computation and Quantum Information.
# 4. Qiskit API documentation for QuantumCircuit and Statevector.
# 5. Qiskit visualization documentation.

# %% [markdown]
# # 17. Appendix – Complete Source Code
#
# This appendix contains the complete source code used for the quantum circuit implementations, simulation functions, visualization functions, and application interface.
